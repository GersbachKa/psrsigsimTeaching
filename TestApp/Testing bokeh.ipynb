# %%
# %load_ext autoreload
# %autoreload 2

# %%
from __future__ import (absolute_import, division, print_function, unicode_literals)
import sys
sys.path.insert(0,'/home/kyle/GWA/NANOGrav/PsrSigSim/')
import psrsigsim as PSS


import bokeh.plotting as bplt
import numpy as np
from psrsigsim import PSS_utils as utils

# %%
psr_dict = {}
psr_dict['f0'] = 1400                   #Central frequency
psr_dict['F0'] = 218                    #Pulsar spin freq
psr_dict['bw'] = 100                    #Bandwidth
psr_dict['Nf'] = 100                    #Frequency bins
psr_dict['ObsTime'] = 30                #Observation time
psr_dict['f_samp'] = 4                  #Sampling frequency
psr_dict['SignalType'] = "intensity"    #'intensity' which carries a Nf x Nt
#filterbank of pulses or 'voltage' which carries a 4 x Nt array of
#voltage vs. time pulses representing 4 stokes channels
psr_dict['dm'] = .5                      #Dispersion Measure Pescs/(CM^3)
# V_ISS -- Intersteller Scintilation Velocity
psr_dict['scint_bw'] =  15.6            #Scintilation Bandwidth
psr_dict['scint_timescale'] = 2630      #Scintilation Timescale
# pulsar -- pulsar name
# telescope -- telescope name(GBT or Arecibo)
psr_dict['freq_band'] = 1400            #Frequency band [327 ,430, 820, 1400, 2300]
# aperature -- aperature (m)
# area -- collecting area (m^2)
# Tsys -- system temp (K), total of receiver, sky, spillover, etc. (only needed for noise)
# name -- GBT or Arecibo
# tau_scatter -- scattering time (ms)
psr_dict['radiometer_noise'] =  False   #radiometer noise
psr_dict['data_type']='int8'            #
psr_dict['flux'] = 3
psr_dict['to_DM_Broaden'] = True

# %%
s1 =  PSS.Simulation(psr =  'J1713+0747' , sim_telescope= 'GBT',sim_ism= True, sim_scint= False, sim_dict = psr_dict,)
s1.simulate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-9566e3e16ce8> in <module>
# ----> 1 s1 =  PSS.Simulation(psr =  'J1713+0747' , sim_telescope= 'GBT',sim_ism= True, sim_scint= False, sim_dict = psr_dict,)
#       2 s1.simulate()
#
# ~/GWA/NANOGrav/PsrSigSim/psrsigsim/simulate.py in __init__(self, psr, sim_telescope, sim_ism, sim_scint, sim_dict, sim_file_path)
#      73
#      74         if isinstance(psr, str):
# ---> 75             self.param_dict = self._set_pulsar_dict()
#      76             print('Five warnings should appear. Warnings that are normal are: Unrecognized parfile line "SOLARN0", "T2CMETHOD", "MODE", "INFO -f". Warning about "DDK model" is also normal.  ')
#      77             if 'F0' in self.param_dict.keys() and 'F0' in self.sim_dict.keys():
#
# ~/GWA/NANOGrav/PsrSigSim/psrsigsim/simulate.py in _set_pulsar_dict(self)
#     283          """
#     284
# --> 285         p = PSS.PSS_utils.get_pint_models(self.psr, self.sim_file_path)
#     286         param_dict = {'F0': p.F0.value, 'dm':p.DM.value}
#     287         [scint_bw, scint_timescale] = PSS.ism.NG_scint_param(self.psr, self.sim_telescope , self.sim_dict['freq_band'])
#
# AttributeError: module 'psrsigsim' has no attribute 'PSS_utils'

# %%
s1.signal.bokeh_filter_bank(notebook = True)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c3d4704b-3579-4d6c-b187-19490f05716c">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8935209a-ac70-4f98-a36b-91bd27fcc743"></div>

# %%
psr_dict['dm'] = 10
s1 =  PSS.Simulation(psr =  'J1713+0747' , sim_telescope= 'GBT',sim_ism= True, sim_scint= False, sim_dict = psr_dict,)
s1.simulate()
s1.signal.bokeh_filter_bank(notebook = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-783aa5616ec6> in <module>
# ----> 1 psr_dict['dm'] = 10
#       2 s1 =  PSS.Simulation(psr =  'J1713+0747' , sim_telescope= 'GBT',sim_ism= True, sim_scint= False, sim_dict = psr_dict,)
#       3 s1.simulate()
#       4 s1.signal.bokeh_filter_bank(notebook = True)
#
# NameError: name 'psr_dict' is not defined

# %%
import h5py

# %%
f = h5py.File('mytestfile.hdf5', 'a')

# %%
dataset = f.create_dataset('Name',shape,datatype)
